# %% [markdown]
# <a href="https://colab.research.google.com/github/PaulASeward/MachineLearning/blob/main/Loading_Datasets_with_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lets load a dataframe using Pandas and then add in the header names after. The data will be from a URL link.

# %%
import pandas as pd
filename= "https://raw.githubusercontent.com/fantasydatapros/data/master/sos/1999.csv"
headernames = "Team,OppPPRFantasyPointsAllowed,PPRSOSRank,OppStandardFantasyPointsAllowed,StandardSOSRank,OppHalfPPRFantasyPointsAllowed,HalfPPRSOSRank,OppRushingFantasyPointsAllowed,RushingSOSRank,OppPassingFantasyPointsAllowed,PassingSOSRank,OppPPRReceivingFantasyPointsAllowed,PPRReceivingSOSRank,OppHalfPPRReceivingFantasyPointsAllowed,HalfPPRReceivingSOSRank,OppStandardReceivingFantasyPointsAllowed,StandardReceivingSOSRank"
headnames = headernames.split(",")
print(headnames)

# Now the headernames are in String list format, I can append them to each clumn with pandas.
nfl_data = pd.read_csv(filename, names=headnames)
nfl_data.head()
# Out:
# ['Team', 'OppPPRFantasyPointsAllowed', 'PPRSOSRank', 'OppStandardFantasyPointsAllowed', 'StandardSOSRank', 'OppHalfPPRFantasyPointsAllowed', 'HalfPPRSOSRank', 'OppRushingFantasyPointsAllowed', 'RushingSOSRank', 'OppPassingFantasyPointsAllowed', 'PassingSOSRank', 'OppPPRReceivingFantasyPointsAllowed', 'PPRReceivingSOSRank', 'OppHalfPPRReceivingFantasyPointsAllowed', 'HalfPPRReceivingSOSRank', 'OppStandardReceivingFantasyPointsAllowed', 'StandardReceivingSOSRank']
#                    Team  OppPPRFantasyPointsAllowed  PPRSOSRank  \
# 0                   NaN  OppPPRFantasyPointsAllowed  PPRSOSRank
# 1        St. Louis Rams          20443.759999999995        31.0
# 2     Carolina Panthers                    19799.04        30.0
# 3  Jacksonville Jaguars                     19632.1        29.0
# 4  Tampa Bay Buccaneers          19523.279999999995        28.0
#
#    OppStandardFantasyPointsAllowed  StandardSOSRank  \
# 0  OppStandardFantasyPointsAllowed  StandardSOSRank
# ...
