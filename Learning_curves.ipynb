# %% [markdown]
# <a href="https://colab.research.google.com/github/PaulASeward/MachineLearning/blob/main/Learning_curves.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.model_selection import learning_curve
from sklearn.naive_bayes import GaussianNB
from sklearn.datasets import load_digits
from matplotlib import pyplot as plt
import numpy as np

X, y = load_digits(return_X_y=True)
naive_bayes = GaussianNB()

train_sizes, train_scores, test_scores = learning_curve(naive_bayes, X, y, cv=30, train_sizes = np.linspace(0.1, 1.0, 9))

train_mean = np.mean(train_scores,axis=1)
test_mean = np.mean(test_scores,axis=1)

plt.plot(train_sizes,train_mean, label='Training Accuracy')
plt.plot(train_sizes,test_mean, label='Validation Accuracy')
plt.title('Learning Curve - Gaussian Naive Bayes')
plt.xlabel('Training Data Size')
plt.ylabel('Model accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
train_std = np.std(train_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.plot(train_sizes,train_mean, label='Training Accuracy')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
plt.plot(train_sizes,test_mean, label='Validation Accuracy')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')
plt.title('Learning Curve - Gaussian Naive Bayes')
plt.xlabel('Training Data Size')
plt.ylabel('Model accuracy')
plt.legend(loc='lower right')
plt.show()
